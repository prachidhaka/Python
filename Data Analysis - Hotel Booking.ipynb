# %%
img_path = r"C:\Users\prachi\Pictures\Screen shots\Screenshot 2024-07-01 172916.png"
Image(filename=img_path)

# %% [markdown]
# # Problem :High cancellations rate

# %% [markdown]
# Data Analysis Project Steps:
# 1. Create a Problem Statement.
# 2. Identify the data you want to analyze.
# 3. Explore and Clean the data.
# 4. Analyze the data to get useful insights.
# 5. Present the data in terms of reports or dashboards using visualization.

# %% [markdown]
# # Import the libraries:

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
#Loading the data :
data = pd.read_csv(r"C:\Users\prachi\Downloads\hotel_bookings 2.csv")
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## EDA and data cleaning :

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
print(df.columns)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date']
# Out:
# 0         1/7/2015
# 1         1/7/2015
# 2         2/7/2015
# 3         2/7/2015
# 4         3/7/2015
#             ...
# 119385    6/9/2017
# 119386    7/9/2017
# 119387    7/9/2017
# 119388    7/9/2017
# 119389    7/9/2017
# Name: reservation_status_date, Length: 119390, dtype: object

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y', dayfirst=True, errors='coerce')
# dayfirst=True ensures dates are interpreted in dd/mm/yyyy format.

# %%
# Check for NaT values
nat_count = df['reservation_status_date'].isna().sum()
print(f'Number of NaT values: {nat_count}')
# Out:
# Number of NaT values: 0

# %%
# Handle NaT values (e.g., fill with a default date)
df['reservation_status_date'].fillna(pd.Timestamp('1970-01-01'), inplace=True)

# %%
# Verify the result
print(df['reservation_status_date'])
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# to get the summary statistics of object column :
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# to get the onject types only we run a for loop :
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50) # for column sepration
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
# return column names and sum of missing values :(quickly counts missing values in each DataFrame column for data cleaning.)
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['agent','company'],axis = 1, inplace = True)
# to make changes in the dataframe we use inplace

# %%
# The dropna() method removes the rows that contains NULL values.
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# Rename the column from 'hotel' to 'Hotel'
df.rename(columns={'hotel': 'Hotel'}, inplace=True)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
# Used for numerical columns to see the stats:

df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df = df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## Data Analysis and Visualizations:

# %%
cancelled_perc  = df['is_canceled'].value_counts(normalize = True)
# (normalize = True) = it will be written the value in percentage

# %%
cancelled_perc
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
cancelled_perc  = df['is_canceled'].value_counts(normalize = True)
print(cancelled_perc)


plt.figure(figsize  = (5,4))
plt.title('Reservation station count' ) 
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(), edgecolor ='k' ,width = 0.7)
plt.show()
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %% [markdown]
# ### The accompanying bar graph shows the percentage of reservations that are canceled amd those are not. it is obivous that are still a significant number of resevations that have ot been canceled .There are still 37% of clients who canceled their reservations ,which has a signidicant impact on the hotels earcnings.

# %%
# to checking data types:
print(df.dtypes)
# Out:
# Hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Convert 'is_canceled' to string type
df['is_canceled'] = df['is_canceled'].astype(str)


plt.figure(figsize=(8,4))
ax1 = sns.countplot(x='Hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))

plt.title('Reservation status in different Hotels', size=20)
plt.xlabel('Hotels')
plt.ylabel('Number of reservations')
plt.show()

# %% [markdown]
# # In comparison to resort hotels , city hotels have more booking. It's possible that resort hotels are more expensive than those in cities.

# %%
# Check unique values in 'Hotel' column
print(df['Hotel'].unique())

# Filter the dataframe for 'Resort Hotel'
resort_hotel = df[df['Hotel'] == 'Resort Hotel']
print(resort_hotel.shape)  # Ensure there are rows in the filtered dataframe

# Calculate the normalized value counts for 'is_canceled'
normalized_counts = resort_hotel['is_canceled'].value_counts(normalize=True)
print(normalized_counts)
# Out:
# ['Resort Hotel' 'City Hotel']
# (39596, 30)
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
city_hotel = df[df['Hotel'] == 'city_hotel']
city_hotel['is_canceled'].value_counts(normalize=True)

# Filter the dataframe for 'City Hotel'
city_hotel = df[df['Hotel'] == 'City Hotel']

# Calculate the normalized value counts for 'is_canceled' for City Hotel
city_normalized_counts = city_hotel['is_canceled'].value_counts(normalize=True)

# Print the normalized counts
print(city_normalized_counts)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
# adr = average daily rate 
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel  = city_hotel .groupby('reservation_status_date')[['adr']].mean()

# %%
# resort_hotel

# %%
# city_hotel

# %%
plt.figure(figsize = (20,8))
plt.title('Average Dily Rate in City and Resort Hotel' , fontsize = 30 )
plt.plot( resort_hotel.index, resort_hotel['adr'] ,label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'] ,label = 'city_hotel')
plt.legend(fontsize = 20)
plt.show()

# %%
# here spickes shown in the chart means ( because of Weekends/Holidays ) price gets hogher . 

# and here we can also say Resort hotel are costly than the city hotels .

# %% [markdown]
# ### This line graphs above shows that, on certain days , the average daily rate for a city hotel is less than that of a resort hotel , and on other days , it is even less. it goes without saying that weekends and holidays may see a rise hotel rates .

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure 'reservation_status_date' is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# first we etract minth from the date columns :( to get the month wise data)
# Extract the month from the 'reservation_status_date' column
df['month'] = df['reservation_status_date'].dt.month

# Verify the new 'month' column
print(df[['reservation_status_date', 'month']].head())
# Out:
#   reservation_status_date  month
# 0              2015-07-01      7
# 1              2015-07-01      7
# 2              2015-07-02      7
# 3              2015-07-02      7
# 4              2015-07-03      7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))

plt.title('Reservation Status Per Month', size=20)
plt.xlabel('Months')
plt.ylabel('Number of Reservations')
plt.legend(['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ### In January, there are typically more cancellations and fewer reservations, whereas August tends to experience higher reservation rates and lower cancellation rates.

# %%
print(df['is_canceled'].unique())
# Out:
# ['0' '1']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# To check the effect of price on  cancellations rate we Plot the average daily rate for each month:

# Filter the DataFrame and group by month, then reset the index
filtered_df = df[df['is_canceled'] == '1'].groupby('month')[['adr']].sum().reset_index()

# Plot if the DataFrame is not empty
plt.figure(figsize=(10, 8))
plt.title('ADR Per Month', fontsize=30)
sns.barplot(x='month', y='adr', data=filtered_df)
plt.show()

# %% [markdown]
# #### This bar grapgh demonstrates that cacelllations are most common when prices are greatest and are least common when they are lowest .Therfore the cost of the accommodation is soley responsible for the cancellations .

# %%
# this prove that when price is higher cancellations are also higher .

# %%
# value_Counts()[:10] -> works as a top 10 decending in sql that we do .

# %%
# Now we analyse by country wise :

cancelled_data = df[df['is_canceled'] == '1']
top_10_country = cancelled_data['country'].value_counts()[:10]

#Plotting the pie chart : 
plt.figure(figsize = (6,6))
plt.title('Top 10 countries with canceled reservations')
plt.pie(top_10_country,autopct = '%.2f', labels = top_10_country.index)
plt.show()

# %%
# here we can see in PRT (Portugal) country their is a huge cancellations :
# we can suggest to hotels that  they should increase facilities more 
# and also should be focus on prices  , give promotional discounts and run campaigns  , marketing etc and decrease these cancellations .

# %% [markdown]
# ### It is coming from Direct or Groups , Online or offline TA ?
# ### Around 46% -> clients are comming from online TA ,whereas 27% come from groups.Only 4% of clients book hotels directly by visiting them and making reservations .

# %%
#  we can now see the clients to get more informations :( use market segment column to the to info) 
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
# To see the percentage : 
df['market_segment'].value_counts(normalize = True )
# get -> Online TA        0.474377
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
# here we can see that percentage of cancelled hotels through online TA ( 46% - out of 47%)
cancelled_data['market_segment'].value_counts(normalize = True )
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %%
# create for not_cancelled :
not_cancelled_data = df[df['is_canceled'] == '0']

# %% [markdown]
# ##### It analyzes and visualizes how the average daily rate (ADR) changes over time for both cancelled and non-cancelled reservations.

# %%
# Group by 'reservation_status_date' and calculate the mean 'adr' for cancelled reservations
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Group by 'reservation_status_date' and calculate the mean 'adr' for non-cancelled reservations
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Plot the results
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate',fontsize = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend(fontsize = 20 )
plt.show()

# %%
# filter the data from (2016 - 2017 sep):{ cancelled and not_cancelled both):

cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016') & (cancelled_df_adr['reservation_status_date']<'2017-09')]

not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016') & (not_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
# Plot the results
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate',fontsize = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend(fontsize = 20 )
plt.show()

# %% [markdown]
# ## The graph indicates that reservations are more likely to be canceled when the average daily rate is higher, confirming that higher prices correlate with increased cancellations.

# %% [markdown]
# ## Suggestions :

# %%
#pip install IPython

# %%
from IPython.display import Image

# %%
# Replace 'path_to_your_image' with the actual path to your image file
img_path = r"C:\Users\prachi\Pictures\Screen shots\Screenshot 2024-07-01 152530.png"
Image(filename=img_path)
