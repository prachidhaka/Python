# %% [markdown]
# #Practice Questions

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
time_day = pd.read_csv(r"C:\Users\prachi\Downloads\time_day.csv")
time_day
# Out:
#    timeId       time
# 0       1  Breakfast
# 1       2      Lunch
# 2       3      Snack
# 3       4     Dinner

# %%
calories = pd.read_csv(r"C:\Users\prachi\Downloads\calories.csv")
calories
# Out:
#             Item  TimeId  Calories   Date New
# 0           Dosa     1.0     400.0   1/1/2024
# 1    Corn Flakes     1.0     250.0   1/1/2024
# 2    Sambar Rice     2.0     220.0   1/1/2024
# 3      Curd Rice     2.0     380.0   1/1/2024
# 4     Potato Fry     2.0     250.0   1/1/2024
# ..           ...     ...       ...        ...
# 110     Snickers     3.0     150.0  1/15/2024
# 111    Curd Rice     4.0     200.0  1/15/2024
# 112         Milk     4.0     150.0  1/15/2024
# 113       Banana     4.0      75.0  1/15/2024
# 114          NaN     NaN       NaN        NaN
#
# [115 rows x 4 columns]

# %%
#write a command to see what type of columns are present
calories.info()
calories.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item      114 non-null    object
#  1   TimeId    114 non-null    float64
#  2   Calories  114 non-null    float64
#  3   Date New  114 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 3.7+ KB
# Index(['Item', 'TimeId', 'Calories', 'Date New'], dtype='object')

# %%
time_day.info()
time_day.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   timeId  4 non-null      int64
#  1   time    4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes
# Index(['timeId', 'time'], dtype='object')

# %%
#show only the first 15 rows of the data
calories.head(15)
# Out:
#               Item  TimeId  Calories  Date New
# 0             Dosa     1.0     400.0  1/1/2024
# 1      Corn Flakes     1.0     250.0  1/1/2024
# 2      Sambar Rice     2.0     220.0  1/1/2024
# 3        Curd Rice     2.0     380.0  1/1/2024
# 4       Potato Fry     2.0     250.0  1/1/2024
# 5             Milk     3.0     150.0  1/1/2024
# 6             Wrap     4.0     350.0  1/1/2024
# 7             Milk     4.0     150.0  1/1/2024
# 8             Dosa     1.0     400.0  1/2/2024
# 9      Corn Flakes     1.0     250.0  1/2/2024
# 10      Rasam Rice     2.0     200.0  1/2/2024
# 11       Curd Rice     2.0     380.0  1/2/2024
# 12  Carrot Veggies     2.0     150.0  1/2/2024
# 13            Milk     3.0     150.0  1/2/2024
# 14           Pasta     4.0     250.0  1/2/2024

# %%
time_day.head(15)
# Out:
#    timeId       time
# 0       1  Breakfast
# 1       2      Lunch
# 2       3      Snack
# 3       4     Dinner

# %%
#convert datenew column to date or datetime type
#convert datenew
calories['Date New'] = calories['Date New'].apply(pd.to_datetime)

# %%
calories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item      114 non-null    object
#  1   TimeId    114 non-null    float64
#  2   Calories  114 non-null    float64
#  3   Date New  114 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 3.7+ KB

# %%
time_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   timeId  4 non-null      int64
#  1   time    4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
#combine calories and time day table with common link
#drop the duplicate time id column
# Join 
#calories table 1
#time_day table 2 
Combined_data = pd.merge(left = calories,right = time_day, left_on = 'TimeId', right_on = 'timeId')

# %%
Combined_data.drop(columns='timeId', inplace=True)

# Drop the column 'timeId' and drop in the existing dataset ( using inplace) 
# Once executed only

# %%
Combined_data
# Out:
#             Item  TimeId  Calories   Date New       time
# 0           Dosa     1.0     400.0 2024-01-01  Breakfast
# 1    Corn Flakes     1.0     250.0 2024-01-01  Breakfast
# 2           Dosa     1.0     400.0 2024-01-02  Breakfast
# 3    Corn Flakes     1.0     250.0 2024-01-02  Breakfast
# 4          Bread     1.0     250.0 2024-01-03  Breakfast
# ..           ...     ...       ...        ...        ...
# 109         Milk     4.0     150.0 2024-01-14     Dinner
# 110       Banana     4.0      75.0 2024-01-14     Dinner
# 111    Curd Rice     4.0     200.0 2024-01-15     Dinner
# 112         Milk     4.0     150.0 2024-01-15     Dinner
# 113       Banana     4.0      75.0 2024-01-15     Dinner
#
# [114 rows x 5 columns]

# %%
#show only the data for breakfast
data_breakfast = Combined_data[Combined_data ['time'] == 'Breakfast']
data_breakfast
# Out:
#            Item  TimeId  Calories   Date New       time
# 0          Dosa     1.0     400.0 2024-01-01  Breakfast
# 1   Corn Flakes     1.0     250.0 2024-01-01  Breakfast
# 2          Dosa     1.0     400.0 2024-01-02  Breakfast
# 3   Corn Flakes     1.0     250.0 2024-01-02  Breakfast
# 4         Bread     1.0     250.0 2024-01-03  Breakfast
# 5   Corn Flakes     1.0     250.0 2024-01-03  Breakfast
# 6         Bread     1.0     250.0 2024-01-04  Breakfast
# 7      Smoothie     1.0     250.0 2024-01-04  Breakfast
# 8          Dosa     1.0     400.0 2024-01-05  Breakfast
# 9   Corn Flakes     1.0     250.0 2024-01-05  Breakfast
# 10         Poha     1.0     200.0 2024-01-06  Breakfast
# 11     Smoothie     1.0     200.0 2024-01-06  Breakfast
# 12  Corn Flakes     1.0     250.0 2024-01-07  Breakfast
# 13   Vermicelli     1.0     200.0 2024-01-08  Breakfast
# 14     Smoothie     1.0     200.0 2024-01-08  Breakfast
# 15        Bread     1.0     250.0 2024-01-09  Breakfast
# ...

# %%
Combined_data
# Out:
#             Item  TimeId  Calories   Date New       time
# 0           Dosa     1.0     400.0 2024-01-01  Breakfast
# 1    Corn Flakes     1.0     250.0 2024-01-01  Breakfast
# 2           Dosa     1.0     400.0 2024-01-02  Breakfast
# 3    Corn Flakes     1.0     250.0 2024-01-02  Breakfast
# 4          Bread     1.0     250.0 2024-01-03  Breakfast
# ..           ...     ...       ...        ...        ...
# 109         Milk     4.0     150.0 2024-01-14     Dinner
# 110       Banana     4.0      75.0 2024-01-14     Dinner
# 111    Curd Rice     4.0     200.0 2024-01-15     Dinner
# 112         Milk     4.0     150.0 2024-01-15     Dinner
# 113       Banana     4.0      75.0 2024-01-15     Dinner
#
# [114 rows x 5 columns]

# %%
#show only data where it is lunch and calories is more than 250
data_lunch = Combined_data[(Combined_data['time']=='Lunch')&(Combined_data['Calories']>250)]

# %%
data_lunch
# Out:
#           Item  TimeId  Calories   Date New   time
# 26   Curd Rice     2.0     380.0 2024-01-01  Lunch
# 29   Curd Rice     2.0     380.0 2024-01-02  Lunch
# 32   Curd Rice     2.0     380.0 2024-01-03  Lunch
# 35   Curd Rice     2.0     380.0 2024-01-04  Lunch
# 38   Curd Rice     2.0     380.0 2024-01-05  Lunch
# 40       Pizza     2.0     400.0 2024-01-06  Lunch
# 43   Curd Rice     2.0     380.0 2024-01-07  Lunch
# 45   Curd Rice     2.0     380.0 2024-01-08  Lunch
# 47   Curd Rice     2.0     380.0 2024-01-09  Lunch
# 49  Fried Rice     2.0     350.0 2024-01-11  Lunch
# 51   Curd Rice     2.0     380.0 2024-01-12  Lunch
# 53   Curd Rice     2.0     380.0 2024-01-13  Lunch
# 56   Curd Rice     2.0     380.0 2024-01-14  Lunch
# 58       Pizza     2.0     400.0 2024-01-15  Lunch

# %%
df = pd.DataFrame(Combined_data)
df
# Out:
#             Item  TimeId  Calories   Date New       time
# 0           Dosa     1.0     400.0 2024-01-01  Breakfast
# 1    Corn Flakes     1.0     250.0 2024-01-01  Breakfast
# 2           Dosa     1.0     400.0 2024-01-02  Breakfast
# 3    Corn Flakes     1.0     250.0 2024-01-02  Breakfast
# 4          Bread     1.0     250.0 2024-01-03  Breakfast
# ..           ...     ...       ...        ...        ...
# 109         Milk     4.0     150.0 2024-01-14     Dinner
# 110       Banana     4.0      75.0 2024-01-14     Dinner
# 111    Curd Rice     4.0     200.0 2024-01-15     Dinner
# 112         Milk     4.0     150.0 2024-01-15     Dinner
# 113       Banana     4.0      75.0 2024-01-15     Dinner
#
# [114 rows x 5 columns]

# %%
#group by timeid and see which had the highest calories intake
calories_per_time  = Combined_data.groupby('time')['Calories'].sum()
calories_per_time
# Out:
# time
# Breakfast    6650.0
# Dinner       6175.0
# Lunch        9150.0
# Snack        2850.0
# Name: Calories, dtype: float64

# %%
#sorting :
#sort the data by calories descending order
df.sort_values (by = ['Calories'] , ascending = False).head()
# Out:
#      Item  TimeId  Calories   Date New       time
# 0    Dosa     1.0     400.0 2024-01-01  Breakfast
# 8    Dosa     1.0     400.0 2024-01-05  Breakfast
# 92   Dosa     4.0     400.0 2024-01-06     Dinner
# 58  Pizza     2.0     400.0 2024-01-15      Lunch
# 19   Dosa     1.0     400.0 2024-01-13  Breakfast

# %%
#show the unique values for Item column 
#How many unique dates does the data have
df['Item'].unique() # in sql we use distinct like that
# Out:
# array(['Dosa', 'Corn Flakes', 'Bread', 'Smoothie', 'Poha', 'Vermicelli',
#        'Puttu', 'Sambar Rice', 'Curd Rice', 'Potato Fry', 'Rasam Rice',
#        'Carrot Veggies', 'Beans', 'Tamarind Rice', 'Chips', 'Pizza',
#        'Cake', 'Cabbage', 'Fried Rice', 'Milk', 'Snickers', 'Dates',
#        'Wrap', 'Pasta', 'Banana', 'Momos'], dtype=object)

# %%
#How many unique dates does the data have
df['Date New'].nunique() # n unique is for count ()
# Out:
# 14

# %%
#rename calories column to intake and time column to time_of_day
# rename columns 
# create a new ap in a dictonary

map = {'Calories' : 'intake','time' : 'time_of_day'}
df= df.rename(columns = map)
df
# Out:
#             Item  TimeId  intake   Date New time_of_day
# 0           Dosa     1.0   400.0 2024-01-01   Breakfast
# 1    Corn Flakes     1.0   250.0 2024-01-01   Breakfast
# 2           Dosa     1.0   400.0 2024-01-02   Breakfast
# 3    Corn Flakes     1.0   250.0 2024-01-02   Breakfast
# 4          Bread     1.0   250.0 2024-01-03   Breakfast
# ..           ...     ...     ...        ...         ...
# 109         Milk     4.0   150.0 2024-01-14      Dinner
# 110       Banana     4.0    75.0 2024-01-14      Dinner
# 111    Curd Rice     4.0   200.0 2024-01-15      Dinner
# 112         Milk     4.0   150.0 2024-01-15      Dinner
# 113       Banana     4.0    75.0 2024-01-15      Dinner
#
# [114 rows x 5 columns]

# %%
#from 12 january to 13 january show % increase in total calories
# calories -> rename to intake

#df.head(16)
agg_data = df.groupby('Date New')['intake'].sum().reset_index()
agg_data
# Out:
#      Date New  intake
# 0  2024-01-01  2150.0
# 1  2024-01-02  2130.0
# 2  2024-01-03  1750.0
# 3  2024-01-04  2055.0
# 4  2024-01-05  2175.0
# 5  2024-01-06  1700.0
# 6  2024-01-07  1530.0
# 7  2024-01-08  1605.0
# 8  2024-01-09  1600.0
# 9  2024-01-11  1225.0
# 10 2024-01-12  1475.0
# 11 2024-01-13  2100.0
# 12 2024-01-14  1805.0
# 13 2024-01-15  1525.0

# %%
agg_data['previousvalue']=agg_data['intake'].shift(1)#similar to lag in sql 
agg_data
# Out:
#      Date New  intake  previousvalue
# 0  2024-01-01  2150.0            NaN
# 1  2024-01-02  2130.0         2150.0
# 2  2024-01-03  1750.0         2130.0
# 3  2024-01-04  2055.0         1750.0
# 4  2024-01-05  2175.0         2055.0
# 5  2024-01-06  1700.0         2175.0
# 6  2024-01-07  1530.0         1700.0
# 7  2024-01-08  1605.0         1530.0
# 8  2024-01-09  1600.0         1605.0
# 9  2024-01-11  1225.0         1600.0
# 10 2024-01-12  1475.0         1225.0
# 11 2024-01-13  2100.0         1475.0
# 12 2024-01-14  1805.0         2100.0
# 13 2024-01-15  1525.0         1805.0

# %%
agg_data['%_change']=(agg_data['intake']-agg_data['previousvalue'])/(agg_data['previousvalue'])# for %change
# Out:
#      Date New  intake  previousvalue  % change   %_change
# 0  2024-01-01  2150.0            NaN        NaN       NaN
# 1  2024-01-02  2130.0         2150.0  -0.009302 -0.009302
# 2  2024-01-03  1750.0         2130.0  -0.178404 -0.178404
# 3  2024-01-04  2055.0         1750.0   0.174286  0.174286
# 4  2024-01-05  2175.0         2055.0   0.058394  0.058394
# 5  2024-01-06  1700.0         2175.0  -0.218391 -0.218391
# 6  2024-01-07  1530.0         1700.0  -0.100000 -0.100000
# 7  2024-01-08  1605.0         1530.0   0.049020  0.049020
# 8  2024-01-09  1600.0         1605.0  -0.003115 -0.003115
# 9  2024-01-11  1225.0         1600.0  -0.234375 -0.234375
# 10 2024-01-12  1475.0         1225.0   0.204082  0.204082
# 11 2024-01-13  2100.0         1475.0   0.423729  0.423729
# 12 2024-01-14  1805.0         2100.0  -0.140476 -0.140476
# 13 2024-01-15  1525.0         1805.0  -0.155125 -0.155125

# %%
#agg_data.drop(columns='%_change', inplace=True)

# %%
agg_data
# Out:
#      Date New  intake  previousvalue  % change
# 0  2024-01-01  2150.0            NaN        NaN
# 1  2024-01-02  2130.0         2150.0  -0.009302
# 2  2024-01-03  1750.0         2130.0  -0.178404
# 3  2024-01-04  2055.0         1750.0   0.174286
# 4  2024-01-05  2175.0         2055.0   0.058394
# 5  2024-01-06  1700.0         2175.0  -0.218391
# 6  2024-01-07  1530.0         1700.0  -0.100000
# 7  2024-01-08  1605.0         1530.0   0.049020
# 8  2024-01-09  1600.0         1605.0  -0.003115
# 9  2024-01-11  1225.0         1600.0  -0.234375
# 10 2024-01-12  1475.0         1225.0   0.204082
# 11 2024-01-13  2100.0         1475.0   0.423729
# 12 2024-01-14  1805.0         2100.0  -0.140476
# 13 2024-01-15  1525.0         1805.0  -0.155125

# %%
#use some function in numpy to create a new column which says small meal if it is snack, otherwise says main meal
#use np.where here 
df['meal']=np.where(df['time_of_day']== 'Snack','small_meal' ,'big_meal')
df
# Out:
#             Item  TimeId  intake   Date New time_of_day      meal
# 0           Dosa     1.0   400.0 2024-01-01   Breakfast  big_meal
# 1    Corn Flakes     1.0   250.0 2024-01-01   Breakfast  big_meal
# 2           Dosa     1.0   400.0 2024-01-02   Breakfast  big_meal
# 3    Corn Flakes     1.0   250.0 2024-01-02   Breakfast  big_meal
# 4          Bread     1.0   250.0 2024-01-03   Breakfast  big_meal
# ..           ...     ...     ...        ...         ...       ...
# 109         Milk     4.0   150.0 2024-01-14      Dinner  big_meal
# 110       Banana     4.0    75.0 2024-01-14      Dinner  big_meal
# 111    Curd Rice     4.0   200.0 2024-01-15      Dinner  big_meal
# 112         Milk     4.0   150.0 2024-01-15      Dinner  big_meal
# 113       Banana     4.0    75.0 2024-01-15      Dinner  big_meal
#
# [114 rows x 6 columns]

# %%
df[df['time_of_day']=='Snack']
# Out:
#         Item  TimeId  intake   Date New time_of_day        meal
# 59      Milk     3.0   150.0 2024-01-01       Snack  small_meal
# 60      Milk     3.0   150.0 2024-01-02       Snack  small_meal
# 61      Milk     3.0   150.0 2024-01-03       Snack  small_meal
# 62      Milk     3.0   150.0 2024-01-04       Snack  small_meal
# 63  Snickers     3.0   150.0 2024-01-04       Snack  small_meal
# 64      Milk     3.0   150.0 2024-01-05       Snack  small_meal
# 65     Dates     3.0   100.0 2024-01-05       Snack  small_meal
# 66      Milk     3.0   150.0 2024-01-06       Snack  small_meal
# 67     Dates     3.0   100.0 2024-01-06       Snack  small_meal
# 68      Milk     3.0   150.0 2024-01-07       Snack  small_meal
# 69      Milk     3.0   150.0 2024-01-08       Snack  small_meal
# 70      Cake     3.0   150.0 2024-01-08       Snack  small_meal
# 71      Milk     3.0   150.0 2024-01-09       Snack  small_meal
# 72      Milk     3.0   150.0 2024-01-11       Snack  small_meal
# ...

# %%
#rows unique values in the column 
unique_values = df['time_of_day'].unique()
print(unique_values)
# Out:
# ['Breakfast' 'Lunch' 'Snack' 'Dinner']

# %% [markdown]
# #pd.set_option('display.max.rows',116)# show all the rows and column of the data .

# %%
df
# Out:
#                Item  TimeId  intake   Date New time_of_day        meal
# 0              Dosa     1.0   400.0 2024-01-01   Breakfast    big_meal
# 1       Corn Flakes     1.0   250.0 2024-01-01   Breakfast    big_meal
# 2              Dosa     1.0   400.0 2024-01-02   Breakfast    big_meal
# 3       Corn Flakes     1.0   250.0 2024-01-02   Breakfast    big_meal
# 4             Bread     1.0   250.0 2024-01-03   Breakfast    big_meal
# 5       Corn Flakes     1.0   250.0 2024-01-03   Breakfast    big_meal
# 6             Bread     1.0   250.0 2024-01-04   Breakfast    big_meal
# 7          Smoothie     1.0   250.0 2024-01-04   Breakfast    big_meal
# 8              Dosa     1.0   400.0 2024-01-05   Breakfast    big_meal
# 9       Corn Flakes     1.0   250.0 2024-01-05   Breakfast    big_meal
# 10             Poha     1.0   200.0 2024-01-06   Breakfast    big_meal
# 11         Smoothie     1.0   200.0 2024-01-06   Breakfast    big_meal
# ...

# %%
#rank the food which had the highest overall intake for breakfast,dinner and so on
# rank food for each time of the day 
rank_data = df.groupby(['time_of_day','Item'])['intake'].sum().reset_index()
rank_data
# Out:
#    time_of_day            Item  intake
# 0    Breakfast           Bread  1000.0
# 1    Breakfast     Corn Flakes  2000.0
# 2    Breakfast            Dosa  1600.0
# 3    Breakfast            Poha   400.0
# 4    Breakfast           Puttu   600.0
# 5    Breakfast        Smoothie   850.0
# 6    Breakfast      Vermicelli   200.0
# 7       Dinner          Banana   525.0
# 8       Dinner       Curd Rice  1400.0
# 9       Dinner            Dosa   700.0
# 10      Dinner            Milk  1950.0
# 11      Dinner           Momos   400.0
# 12      Dinner           Pasta   500.0
# 13      Dinner            Wrap   700.0
# 14       Lunch           Beans   300.0
# 15       Lunch         Cabbage   300.0
# 16       Lunch            Cake   100.0
# 17       Lunch  Carrot Veggies   150.0
# 18       Lunch           Chips   100.0
# 19       Lunch       Curd Rice  4180.0
# 20       Lunch      Fried Rice   350.0
# 21       Lunch           Pizza   800.0
# 22       Lunch      Potato Fry   750.0
# ...

# %%
# rank it 
rank_data['rank']= rank_data.groupby('time_of_day')['intake'].rank(method = 'first',ascending = False)
rank_data
# Out:
#    time_of_day            Item  intake  rank
# 0    Breakfast           Bread  1000.0   3.0
# 1    Breakfast     Corn Flakes  2000.0   1.0
# 2    Breakfast            Dosa  1600.0   2.0
# 3    Breakfast            Poha   400.0   6.0
# 4    Breakfast           Puttu   600.0   5.0
# 5    Breakfast        Smoothie   850.0   4.0
# 6    Breakfast      Vermicelli   200.0   7.0
# 7       Dinner          Banana   525.0   5.0
# 8       Dinner       Curd Rice  1400.0   2.0
# 9       Dinner            Dosa   700.0   3.0
# 10      Dinner            Milk  1950.0   1.0
# 11      Dinner           Momos   400.0   7.0
# 12      Dinner           Pasta   500.0   6.0
# 13      Dinner            Wrap   700.0   4.0
# 14       Lunch           Beans   300.0   7.0
# 15       Lunch         Cabbage   300.0   8.0
# 16       Lunch            Cake   100.0  11.0
# 17       Lunch  Carrot Veggies   150.0  10.0
# 18       Lunch           Chips   100.0  12.0
# 19       Lunch       Curd Rice  4180.0   1.0
# ...

# %% [markdown]
# # plotting

# %%
#plot the time categories and overall calories using some plotting function
import matplotlib.pyplot as plt
plot_data=df.groupby('time_of_day')['intake'].sum()
plot_data
plt.bar(plot_data.index,plot_data.values)
# Out:
# <BarContainer object of 4 artists>

# %%
#Write a code to find rows which contain the item name as pasta
df['Find_Pasta'] = df['Item'].str.find('Pasta')#81,94
df[df['Find_Pasta']>=0]
# Out:
#      Item  TimeId  intake   Date New time_of_day      meal  Find_Pasta
# 81  Pasta     4.0   250.0 2024-01-02      Dinner  big_meal           0
# 94  Pasta     4.0   250.0 2024-01-07      Dinner  big_meal           0

# %%
#Write a for loop to display only the multiples of 5 starting from 5 to 45
for i in range (5,46,5):
    print(i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %%
#Write a simple for loop to display squares of numbers from 1 to 9
for i in range(1,10,1):
        print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
#write a simple code to declare a variable a as 8 and an if statement to say if value is greater than 8 or not
a=8
if (a > 8):
    print('a is greter than 8')
else :
    print ('a is not above 8')

#a=8
#for i in range(1,10,1):
#    if i > 8:
#        print('a is greater than 8 ')
#    else:
#       print('a is not greater than 8 ')
#or
# Out:
# a is not above 8

# %%
#declare a simple list b with 4 values 0,1,2,3 and write a for loop using try and except 
#for running i values from 0 to 6( when there is no value print value unavailable)

b =[0,1,2,3]

try: 
    for i in range (0,6) :
         print(b[i])
except IndexError:
    print ('value unavailable')
        
        
#for i in range (0,6,1) :
#    print(i)
#else:
#    print("value unavailable")
# Out:
# 0
# 1
# 2
# 3
# value unavailable

# %% [markdown]
# # -=-=-=finish=-#=-=-
